# %%
# Importing the necessary packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

#Some Matplotlib settings
from pylab import rcParams
rcParams['figure.figsize'] = 30, 20
plt.rc('axes', labelsize='35')
plt.xticks(fontsize='30')
plt.yticks(fontsize='30')
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 6 Text major ticklabel objects>)

# %%
# Now we need the full GRB data for plotting various histograms.

df = pd.read_excel('to_process_in_python.xlsx')

# %%
df
# Out:
#     GRB Name  Obs_ID       z     1+z  T90_raw(s)  T90_raw_error  T50_raw(s)  \
# 0    180728A  850471   0.117  1.1170       8.688          0.321       2.464
# 1      60614  214805   0.127  1.1380     109.264          3.415      43.296
# 2    150727A  650530   0.313  1.3130      86.128         12.748      30.192
# 3    130427A  554620    0.34  1.3400     316.272          7.630      32.064
# 4      61021  234905  0.3463  1.3463      46.448          5.200      10.240
# ..       ...     ...     ...     ...         ...            ...         ...
# 242    60927  231362     5.6  6.6000      22.528          1.277      15.792
# 243  130606A  557589   5.913  6.9130     163.088          2.983      71.696
# 244    50904  153514     6.2  7.2000     179.500         10.300      85.400
# 245  140515A  599037    6.32  7.3200      23.456          2.048       9.776
# 246    90423  350184    8.05  9.0500      10.624          1.008       4.864
#
# ...

# %%
#Dropping the unnecessary columns other than z and burst intervals

df.drop(["GRB Name"],axis=1,inplace=True)
df.drop(["Obs_ID"],axis=1,inplace=True)
#df.drop(["z"],axis=1,inplace=True)
df.drop(["1+z"],axis=1,inplace=True)
#df.drop(["T90_raw(s)"],axis=1,inplace=True)
df.drop(["T90_raw_error"],axis=1,inplace=True)
#df.drop(["T50_raw(s)"],axis=1,inplace=True)
df.drop(["T50_raw_error"],axis=1,inplace=True)
df.drop(["E1_obsframe(KeV)"],axis=1,inplace=True)
df.drop(["E2_obsframe(KeV)"],axis=1,inplace=True)

# %%
df
# Out:
#      T90_raw(s)  T50_raw(s)  T90_(s)  T90_error  T50_(s)  T50_error
# 0         8.688       2.464    5.280      2.197    1.824      0.230
# 1       109.264      43.296   18.320      4.113   11.344      6.051
# 2        86.128      30.192   23.904      4.388   14.976      6.150
# 3       316.272      32.064  128.336      4.859    4.016      0.079
# 4        46.448      10.240    4.928      0.861    2.128      0.714
# ..          ...         ...      ...        ...      ...        ...
# 242      22.528      15.792   21.248      1.395   16.320      5.891
# 243     163.088      71.696  163.344      2.805   77.296     64.377
# 244     179.500      85.400  187.744     14.269   87.216      8.845
# 245      23.456       9.776   23.136      1.958   10.048      5.955
# 246      10.624       4.864   12.960      2.808    5.296      0.581
#
# [247 rows x 6 columns]

# %% [markdown]
# # #Histograms for burst intervals

# %%
#Histograms for burst intervals

T50=np.log10(df["T50_(s)"])
T90=np.log10(df["T90_(s)"])
T50_raw=np.log10(df["T50_raw(s)"])
T90_raw=np.log10(df["T90_raw(s)"])

# %%
# Plotting histogram for T50


#Some Matplotlib settings
from pylab import rcParams
rcParams['figure.figsize'] = 30, 20
plt.rc('axes', labelsize='35')
plt.xticks(fontsize='30')
plt.yticks(fontsize='30')


import seaborn as sns
sns.distplot(T50, hist=True, kde=True, 
             bins=12, color = 'darkblue', 
             hist_kws={'edgecolor':'white'},
             kde_kws={'linewidth': 4})


plt.xlabel("log $T_{50}$",fontsize='40')
plt.ylabel("Number of bursts",fontsize='40')
plt.grid()

# %%
# Plotting histogram for T90


#Some Matplotlib settings
from pylab import rcParams
rcParams['figure.figsize'] = 30, 20
plt.rc('axes', labelsize='35')
plt.xticks(fontsize='30')
plt.yticks(fontsize='30')


import seaborn as sns
sns.distplot(T90, hist=True, kde=True, 
             bins=12, color = 'darkblue', 
             hist_kws={'edgecolor':'white'},
             kde_kws={'linewidth': 4})


plt.xlabel("log $T_{90}$",fontsize='40')
plt.ylabel("Number of bursts",fontsize='40')
plt.grid()

# %%
# Plotting histogram for T50_raw


#Some Matplotlib settings
from pylab import rcParams
rcParams['figure.figsize'] = 30, 20
plt.rc('axes', labelsize='35')
plt.xticks(fontsize='30')
plt.yticks(fontsize='30')


import seaborn as sns
sns.distplot(T50_raw, hist=True, kde=True, 
             bins=12, color = 'darkblue', 
             hist_kws={'edgecolor':'white'},
             kde_kws={'linewidth': 4})


plt.xlabel("log $T_{50,raw}$",fontsize='40')
plt.ylabel("Number of bursts",fontsize='40')
plt.grid()

# %%
# Plotting histogram for T90_raw


#Some Matplotlib settings
from pylab import rcParams
rcParams['figure.figsize'] = 30, 20
plt.rc('axes', labelsize='35')
plt.xticks(fontsize='30')
plt.yticks(fontsize='30')


import seaborn as sns
sns.distplot(T90_raw, hist=True, kde=True, 
             bins=12, color = 'darkblue', 
             hist_kws={'edgecolor':'white'},
             kde_kws={'linewidth': 4})


plt.xlabel("log $T_{90,raw}$",fontsize='40')
plt.ylabel("Number of bursts",fontsize='40')
plt.grid()

# %% [markdown]
# # #Histograms for redshift

# %%
z=df["z"]

#Some Matplotlib settings
from pylab import rcParams
rcParams['figure.figsize'] = 30, 20
plt.rc('axes', labelsize='35')
plt.xticks(fontsize='30')
plt.yticks(fontsize='30')


import seaborn as sns
sns.distplot(z, hist=True, kde=True, 
             bins=12, color = 'darkblue', 
             hist_kws={'edgecolor':'white'},
             kde_kws={'linewidth': 4})


plt.xlabel("Redshifts",fontsize='40')
plt.ylabel("Number of bursts",fontsize='40')
plt.grid()
